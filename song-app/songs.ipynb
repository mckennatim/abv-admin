# %% [markdown]
# # setup

# %%
## setup
import abv
from importlib import reload
reload(abv)
from pathlib import Path
import os
import json
from bs4 import BeautifulSoup
import shutil

# run from this relative folder
uploads_relative = "../uploads/"
songs_relative = "../songs/"
local_host = "http://localhost/abv/public_html/"
abv_host = "https://abvchorus.org/"
remote_dir = "public_html/"
link_ref = ""

# %%
from flask import Flask, request, jsonify, send_from_directory
from flask_cors import CORS
import sqlite3
import os
import sys
import json
import logging
import re
import subprocess
import tempfile
import shutil
from werkzeug.utils import secure_filename
import abv
from importlib import reload

# %% [markdown]
# to start the server, from song-app/server folder
# ```bash
# ./restart-abv.sh
#
# tail -f nohup.out
# ```
